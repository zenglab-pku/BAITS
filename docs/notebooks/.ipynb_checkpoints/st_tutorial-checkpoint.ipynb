# %% [markdown]
# # BAITS.st.module tutorial

# %% [markdown]
# This tutorial shows an example of B lymphocyte aggregates (BLAs) identification. The dataset is composed of 2 human liver metastatic colorectal tumor samples profiled by Stereo-seq from originial paper.

# %% [markdown]
# Let’s first load the packages and data that will be necessary for the analysis.

# %% [markdown]
# ## Import packages and data

# %%
# import BAITS
import os
import scanpy as sc

# %%
os.chdir('/home/zhaoyp/1.CRLM_XCR/BAITS') 
import BAITS

# %% [markdown]
# **Users could access data through the following [link](https://baits.pku-genomics.org/#/download)**

# %%
adata = sc.read("/home/zhaoyp/1.CRLM_XCR/BAITS_temp/data/twosamples.h5ad")

# %%
adata

# %% [markdown]
# ## Data preprocessing

# %%
# Normalizing to median total counts
sc.pp.normalize_total(adata)

# Logarithmize the data
sc.pp.log1p(adata)

# %% [markdown]
# ## Identify B lymphocytes enriched regions

# %% [markdown]
# Defining the B cell-related gene set

# %%
signature = ["CD79A", "CD79B", "MS4A1", "CD79A", 'CD79B', "MZB1", "JCHAIN", "IGHA1", 'IGHG1', 'IGHG3']

# %% [markdown]
# Custom score name

# %%
score_name = 'Bcell_enrichment'

# %% [markdown]
# Assign the column name in `adata.obs` that identifies samples. Based on this parameter, **BAITS** will process each sample separately to reduce the batch effect.

# %%
sample_name = 'sample'

# %% [markdown]
# ### Step1: Calculate the score

# %%
sc.tl.score_genes(adata, gene_list=signature, score_name=score_name)

# %% [markdown]
# ### Step2: Filtering

# %% [markdown]
# By using function **BAITS.st.tl.kde_filter**, we could filter cells with low B-cell-score

# %%
from joblib import Parallel, delayed
from sklearn.neighbors import KernelDensity
from collections import defaultdict
import numpy as np
from scipy.ndimage import binary_opening
import multiprocessing
import time
import warnings
warnings.filterwarnings('ignore') 

def calculate_density(kde, pos):
    return np.exp(kde.score_samples([pos]))
    
def kde_filter(adata_tmp,
               score_name,
               high_binSize = 100,
               default_thread_num=36,
               clean_mask_size=(3,3) ):
    
    """
    Filter spatial transcriptomics (ST) data using Kernel Density Estimation (KDE).

    Parameters
    ----------
    adata_tmp : AnnData object
        The input AnnData object containing spatial and score data.
    score_name : str
        The name of the column in `adata_tmp.obs` that contains the scores to be used as weights.
    high_binSize : int, optional (default: 100)
        The size of the bins used for spatial discretization.
    default_thread_num : int, optional (default: 36)
        The maximum number of threads to use for parallel KDE scoring.
    clean_mask_size : tuple of int, optional (default: (3, 3))
        The size of the structuring element used for binary opening during mask cleaning.

    Returns
    -------
    AnnData
        A subset of the input AnnData object, filtered to retain only the valid spatial coordinates.

    """
    
    if score_name is not None:
        adata_tmp = adata_tmp[adata_tmp.obs[score_name] > 0].copy()
    
    # original locations 
    start_time = time.time()
    positions_original = adata_tmp.obsm['spatial']

    # prepare
    x = np.array(positions_original[:, 0]); y = np.array(positions_original[:, 1])
    x_min, x_max = x.min(), x.max()
    y_min, y_max = y.min(), y.max()
    Z = np.array(adata_tmp.obs[score_name]).astype(np.float32)
    high_binSize = high_binSize
    bandwidth = int( high_binSize / 3 )
    points = np.vstack([x, y]).T  

    # record original coords
    xy_dict = defaultdict(list)   
    for i in range(len(x)):
        Bx = (x[i] - x_min) // high_binSize * high_binSize + x_min
        By = (y[i] - y_min) // high_binSize * high_binSize + y_min
        xy_dict[(Bx, By)].append([x[i], y[i]])  # 直接追加，无需检查键是否存在
        
    # kde fit
    kde = KernelDensity(kernel='gaussian', bandwidth=bandwidth)
    kde.fit(points, sample_weight=Z)   
    x_grid, y_grid = np.meshgrid(np.arange(x_min,x_max,high_binSize), np.arange(y_min,y_max,high_binSize)) 
    positions = np.vstack([x_grid.ravel(), y_grid.ravel()]).T     # 	np.vstack 是 np.concatenate 函数的一个方便函数，等价于 np.concatenate，但指定了 axis=0 即在第一个轴（行）上进行堆叠
    x_grid = x_grid.astype(np.float32); y_grid = y_grid.astype(np.float32); positions = positions.astype(np.float32)
    print(f"🔎 Step 1 - Process data:\t{time.time() - start_time:.2f} s")
    
    # kde score
    start_time = time.time()
    num_cores = min(multiprocessing.cpu_count(), default_thread_num)
    density = Parallel(n_jobs=num_cores)(delayed(calculate_density)(kde, pos) for pos in positions) 
    density = (np.array(density).reshape(x_grid.shape))    
    print(f"🏋️ Step 2 - KDE scoring:\t{time.time() - start_time:.2f} s")

    # set density cutoff
    start_time = time.time()
    density_flat = density.ravel()
    # threshold = np.percentile(density_flat, 50) 
    threshold = np.mean(density_flat)                ################### Cutoff is setting as mean value  ###################

    density_thresholded = np.where(density > threshold, density, np.nan)
    binary_mask = ~np.isnan(density_thresholded)
    cleaned_mask = binary_opening(binary_mask, structure=np.ones(clean_mask_size))
    density_cleaned = np.where(cleaned_mask, density, np.nan) 
    mask = ~np.isnan(density_cleaned)
    x_coords = x_grid[mask]
    y_coords = y_grid[mask]

    adata_tmp.uns["binary_mask"] = binary_mask
    adata_tmp.uns["mask"] = mask
    
    coords = np.vstack([x_coords, y_coords]).T
    orginal_coords = []
    for coord in coords:
        orginal_coords += (xy_dict[tuple(coord)])

    # obtain the legal coords
    original_coords_set = {tuple(row) for row in orginal_coords}
    isin_ = [tuple(x) in original_coords_set for x in positions_original]
    print(f"🔬 Step 3 - Obtain correct coords:\t{time.time() - start_time:.2f} s")
    print()

    adata_tmp.obs['filtered_coords'] = isin_

    return adata_tmp[isin_]

# %%
filtered_adata = []
for sample in set(adata.obs[sample_name]):
    tmp_ad = adata[adata.obs[sample_name]==sample].copy()
    tmp_res = BAITS.st.tl.kde_filter(tmp_ad, score_name=score_name)
    filtered_adata.append(tmp_res)

# %%
BAITS.st.tl.kde_filter

# %% [markdown]
# We filter the cells by **B_HIT.st.tl.kde_filter**, plot them by **B_HIT.st.pl.enrichment_score**, visualizing the results.

# %%
result = BAITS.st.tl.batch_process( 
    
    adata=adata, sample_name=sample_name, score_name=score_name,   
    processing_func=BAITS.st.tl.kde_filter, 
    verbose=True,
    func_kwargs={ 'score_name':score_name, 'high_binSize': 100, 'default_thread_num': 36, 'clean_mask_size': (3,3)}
)
# Out:
# 🔬 Start process sample:	P1121_LM
# 🔎 Step 1 - Process data: 0.68 s
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/zhaoyp/miniconda3/envs/BAITS/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 453, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/home/zhaoyp/miniconda3/envs/BAITS/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
# ModuleNotFoundError: No module named 'BAITS'
# """
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 result = BAITS.st.tl.batch_process(
#       2
# ...

# %% [markdown]
# ### Step3: Cluster

# %% [markdown]
# **st.tl.dbscan_filter** used DBSCAN algorithm to cluster the spatially close domains

# %%
result = B_HIT.st.tl.batch_process( 
    
    adata=adata, sample_name=sample_name, score_name=score_name,   
    processing_func=B_HIT.st.tl.dbscan_cluster, 
    verbose=True,
    func_kwargs={ 'eps': 100, 'min_samples': 50, 'plot': True }     
)
# Out:
# ============ Processing sample: P1121_LM ============
# ...
# ============ Finished sample: P1121_LM ============
#
# ============ Processing sample: P0516_LM ============
# ...
# ============ Finished sample: P0516_LM ============

# %% [markdown]
# ## Cluster by gene-expression and spatial location

# %% [markdown]
# Except for clustering the spatially close cells, we can also cluster the gene-expression similar domains.
# In this part, we will spatial cluster the domains based on CellCharter.

# %% [markdown]
# ### Gene expression matrix process

# %% [markdown]
# Dimensionality reduction - Reduce the dimensionality of the data by running principal component analysis (PCA), which reveals the main axes of variation and denoises the data.

# %%
sc.tl.pca(adata)

# %% [markdown]
# Integrate gene expression matrix of multi samples

# %%
sc.external.pp.harmony_integrate(adata, key='sample', basis='X_pca' )
# Out:
# 2025-05-08 14:40:54,279 - harmonypy - INFO - Computing initial centroids with sklearn.KMeans...
# 2025-05-08 14:42:27,850 - harmonypy - INFO - sklearn.KMeans initialization complete.
# 2025-05-08 14:42:35,519 - harmonypy - INFO - Iteration 1 of 10
# 2025-05-08 14:54:29,604 - harmonypy - INFO - Iteration 2 of 10
# 2025-05-08 15:06:15,858 - harmonypy - INFO - Iteration 3 of 10
# 2025-05-08 15:18:21,308 - harmonypy - INFO - Iteration 4 of 10
# 2025-05-08 15:25:56,194 - harmonypy - INFO - Iteration 5 of 10
# 2025-05-08 15:32:27,675 - harmonypy - INFO - Iteration 6 of 10
# 2025-05-08 15:36:02,300 - harmonypy - INFO - Iteration 7 of 10
# 2025-05-08 15:39:37,813 - harmonypy - INFO - Iteration 8 of 10
# 2025-05-08 15:43:02,764 - harmonypy - INFO - Iteration 9 of 10
# 2025-05-08 15:46:53,296 - harmonypy - INFO - Iteration 10 of 10
# 2025-05-08 15:50:41,937 - harmonypy - INFO - Stopped before convergence

# %% [markdown]
# adata

# %% [markdown]
# ### Spatial clustering - 1 (cellCharter)

# %% [markdown]
# It is now time to compute the spatial clusters. All cells of each sample are encoded into networks. Every cell is a node and two cells are connected by an edge if they are physically close to each other in the tissue.

# %%
B_HIT.st.gr.spatial_neighbors(adata, sample_key='sample', coord_type='generic', delaunay=True, spatial_key='spatial')

# %% [markdown]
# The next step is the neighborhood aggregation. It consists of concatenating the features of every cell with the features aggregated from neighbors ad increasing layers from the considered cell, up to a certain layer n_layers. Aggregation functions are used to obtain a single feature vector from the vectors of multiple neighbors, with the default being the mean function.
#
# In this case we use 3 layers of neighbors, so we obtain, for each cell, a feature vector of length 40. That is the cell’s reduced vector size from trVAE (10) plus the 3 aggregated vectors of length 10 each, from the 3 layers of neighbors.

# %%
B_HIT.st.gr.aggregate_neighbors(adata, n_layers=3, use_rep='X_pca')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 2/2 [00:25<00:00, 12.71s/it]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 968003 × 25091
#     obs: 'n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'celltype', 'sample', 'Bcell_enrichment'
#     var: 'mt'
#     uns: 'spatial_neighbors', 'pca'
#     obsm: 'spatial', 'X_pca', 'X_cellcharter'
#     varm: 'PCs'
#     obsp: 'spatial_connectivities', 'spatial_distances'

# %% [markdown]
# We create the Gaussian Mixture model, specifying 12 as desired number of clusters. This value was obtained from the cluster stability analysis. For more details, you can check our paper.

# %%
gmm = B_HIT.st.tl.Cluster(
    n_clusters=11, random_state=12345,
    # If running on GPU 
    # trainer_params=dict(accelerator='gpu', devices=1)
)

# %%
gmm.fit(adata, use_rep='X_cellcharter')
adata.obs['spatial_cluster'] = gmm.predict(adata, use_rep='X_cellcharter')
# Out:
# Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ...

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 968003 × 25091
#     obs: 'n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'celltype', 'sample', 'Bcell_enrichment', 'spatial_cluster'
#     var: 'mt'
#     uns: 'spatial_neighbors', 'pca', '_cellcharter'
#     obsm: 'spatial', 'X_pca', 'X_cellcharter'
#     varm: 'PCs'
#     obsp: 'spatial_connectivities', 'spatial_distances'

# %%
sc.pl.spatial(adata[adata.obs['sample']=='P0516_LM'], color=['spatial_cluster'], spot_size=50, palette='Set2')

# %% [markdown]
# ### Spatial clustering - 2 (cellCharter)

# %% [markdown]
# if you want to use CellCharter’s stability analysis to suggest the best candidates for the number of clusters, you can use the tl.ClusterAutoK class.
# It is going to repeat max_runs times the clustering for each value K in the range provided in the n_clusters parameter and it will compute the stability between adjacent Ks, as described in CellCharter’s paper. If the stability curve between two runs doesn’t change by more than the convergence_tol parameter, the process will complete early without running the full max_runs times.
#
# Of course, this will increase the computational time, but the scalability of CellCharter’s clustering step makes this analysis tractable even for large-scale datasets.

# %%
B_HIT.st.gr.spatial_neighbors(adata, sample_key='sample', coord_type='generic', delaunay=True, spatial_key='spatial')

# %%
B_HIT.st.gr.aggregate_neighbors(adata, n_layers=3, use_rep='X_pca')
# Out:
# 100%|██████████████████████████████████████████████████████████| 2/2 [00:20<00:00, 10.47s/it]

# %%
autok = B_HIT.st.tl.ClusterAutoK(
    n_clusters=(5,15), 
    max_runs=3,
    convergence_tol=0.001
)

# %%
autok.fit(adata, use_rep='X_cellcharter')
# Out:
# Iteration 1/3
#   0%|                                                                 | 0/12 [00:00<?, ?it/s]Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ...

# %%
1

# %%
cc.pl.autok_stability(autok)

# %%
silhouette_scores

# %%
adata.obs['cluster_cellcharter'] = autok.predict(adata, use_rep='X_cellcharter')

# %%
sq.pl.spatial_scatter(
    adata, 
    color=['cluster_cellcharter'], 
    library_key='sample',  
    size=30, 
    img=None,
    spatial_key='spatial_fov',
    palette='Set2',
    figsize=(5,5),
    ncols=1,
    library_id=['Lung9_Rep1'],
)
